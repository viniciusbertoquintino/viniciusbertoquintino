# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 3.1/3.1 MB 23.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: duckduckgo_search
#     Found existing installation: duckduckgo_search 6.1.12
#     Uninstalling duckduckgo_search-6.1.12:
#       Successfully uninstalled duckduckgo_search-6.1.12
# ...
